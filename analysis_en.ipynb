# %% [markdown]
# # Preprocessing
#
# ## Formatting the annotation data

# %% [markdown]
# ## Uploading data in Google Colab
#
# After obtaining the data, run this cell in Colab to upload the CSV files to `data/`. The files are removed when the Colab runtime ends.

# %%
from pathlib import Path

try:
    from google.colab import files
except ImportError:
    pass
else:
    data_dir = Path("data")
    data_dir.mkdir(exist_ok=True)
    uploaded = files.upload()
    for name, content in uploaded.items():
        (data_dir / name).write_bytes(content)

# %%
import numpy as np
import pandas as pd

# %%
# This code will not run when data/ is empty; see the README to download and place the data.
df_a = pd.read_csv("data/Thai_adults_tournament.csv").set_index("order_no/id")
subj_idx_a = df_a.columns.to_list()
language_a = ["Adult" for _ in subj_idx_a]
strokes_a = [" ".join(row) for row in df_a.to_numpy().T.astype(str)]

df_t = pd.read_csv("data/Thai_child_tournament.csv").set_index("order_no/id")
subj_idx_t = df_t.columns.to_list()
language_t = ["Child" for _ in subj_idx_t]
strokes_t = [" ".join(row) for row in df_t.to_numpy().T.astype(str)]

# %%
df = pd.DataFrame({
    "subj_idx": subj_idx_a+subj_idx_t,
    "age": language_a+language_t,
    "strokes": strokes_a+strokes_t,
})
df
# Out:
#     subj_idx    age                                            strokes
# 0   adults-1  Adult  rank3 rank2_1 rank2_1 rank2_2 rank2_2 rank2_2 ...
# 1   adults-2  Adult  rank1_1 rank1_1 rank1_2 rank1_2 rank2_1 rank2_...
# 2   adults-3  Adult  rank3 rank2_1 rank2_1 rank1_1 rank1_2 rank2_2 ...
# 3   adults-4  Adult  rank1_1 rank1_2 rank2_1 rank1_3 rank1_4 rank2_...
# 4   adults-5  Adult  rank3 rank2_1 rank2_2 rank1_1 rank1_2 rank1_3 ...
# ..       ...    ...                                                ...
# 70  child-36  Child  rank3 rank2_1 rank2_2 rank1_1 rank1_2 rank1_3 ...
# 71  child-37  Child  rank1_1 rank1_2 rank1_3 rank1_4 rank2_1 rank2_...
# 72  child-38  Child  rank1_1 rank2_1 rank2_1 rank3-rank2_2-rank1_4 ...
# 73  child-39  Child  rank1_1 rank1_2 rank1_3 rank1_3 rank1_4 rank2_...
# 74  child-40  Child  rank3 rank2_1 rank2_1 rank2_1 rank2_2 rank2_2 ...
#
# [75 rows x 3 columns]

# %%
len(set(" ".join(df.strokes).split())) - 1
# Out:
# 16

# %% [markdown]
# ## Extracting text features

# %%
from sklearn.feature_extraction.text \
    import CountVectorizer

# %%
n_gram = 2

vectorizer = CountVectorizer(
    stop_words=["nan", "extra", "point"],
    ngram_range=(1, n_gram),
)
corpus = df.strokes
vectorizer.fit(corpus)
# Out:
# CountVectorizer(ngram_range=(1, 2), stop_words=['nan', 'extra', 'point'])

# %%
X = vectorizer.transform(corpus).toarray()
cols = vectorizer.get_feature_names_out()
cols = list(map(lambda s: s.replace(" ", "-"), cols))
df_bow = pd.DataFrame(X, columns=cols)

# %%
y = df.age == "Child"
y = y.astype(int)
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 70    1
# 71    1
# 72    1
# 73    1
# 74    1
# Name: age, Length: 75, dtype: int64

# %% [markdown]
# ## Visualization and interpretation

# %%
from sklearn.linear_model \
    import LogisticRegression

# %%
C = 1
lr_l1 = LogisticRegression(C=C,
                           penalty='l1',
                           solver='liblinear')
lr_l1.fit(X, y)  # estimate Beta
coef = lr_l1.coef_.flatten()
non_zero = coef != 0
sum(non_zero)
# Out:
# /tmp/jcss-notebook-venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /tmp/jcss-notebook-venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# np.int64(12)

# %%
from plotnine import *
from IPython.display import display

res = pd.DataFrame(
    {"coef": coef[non_zero],
     "feature":np.array(cols)[non_zero]})
res = res.sort_values("coef", ascending=False)
# Use ascending categorical levels so the largest coefficient is at the top.
res["feature"] = pd.Categorical(
    res["feature"], categories=res["feature"].iloc[::-1], ordered=True)
p = (ggplot(res, aes(x='coef', y='feature'))
     + geom_point()
     )
display(p)
p.save(f'fig/coef_{C}.pdf', height=7, width=7, units="cm")
# Out:
# /tmp/jcss-notebook-venv/lib/python3.12/site-packages/plotnine/ggplot.py:623: PlotnineWarning: Saving 7.0 x 7.0 cm image.
# /tmp/jcss-notebook-venv/lib/python3.12/site-packages/plotnine/ggplot.py:624: PlotnineWarning: Filename: fig/coef_1.pdf
